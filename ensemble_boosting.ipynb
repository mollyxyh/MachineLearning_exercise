# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import r2_score, mean_squared_error

from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# ### AdaBoost
#
# AdaBoost: each learner pays more attention to training instances that were underfitted by previous weak learner

# %%
concrete_data = pd.read_csv('dataset/concrete_data.csv')

X = concrete_data.drop('csMPa', axis=1)
Y = concrete_data['csMPa']

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
ada_reg = AdaBoostRegressor(DecisionTreeRegressor(max_depth=4), 
                           n_estimators=100, 
                           learning_rate=1.0) #usually set at 0.01 or 0.001 to prevent overfitting

ada_reg.fit(x_train, y_train)
# Out:
# AdaBoostRegressor(base_estimator=DecisionTreeRegressor(criterion='mse',
#                                                        max_depth=4,
#                                                        max_features=None,
#                                                        max_leaf_nodes=None,
#                                                        min_impurity_decrease=0.0,
#                                                        min_impurity_split=None,
#                                                        min_samples_leaf=1,
#                                                        min_samples_split=2,
#                                                        min_weight_fraction_leaf=0.0,
#                                                        presort=False,
#                                                        random_state=None,
#                                                        splitter='best'),
#                   learning_rate=1.0, loss='linear', n_estimators=100,
#                   random_state=None)

# %%
ada_reg.estimator_weights_
# Out:
# array([1.70036247, 1.36254712, 1.42035226, 1.19954412, 1.26750077,
#        1.19688718, 0.92264566, 1.10433941, 1.01040021, 1.12585885,
#        1.37222715, 0.67406631, 1.04942413, 1.55446746, 1.10637091,
#        1.02583973, 1.19732748, 0.91087722, 0.99717036, 0.82595785,
#        1.39374631, 1.01661025, 0.81198543, 0.97427925, 0.7127864 ,
#        0.75710123, 0.6233892 , 0.76471728, 0.76729913, 0.71631205,
#        0.78545807, 1.13766242, 0.97835529, 0.88213221, 1.31667113,
#        1.04231765, 0.60093768, 0.66914071, 0.91573149, 0.74007343,
#        0.8106807 , 0.66889768, 0.86014538, 0.77128369, 0.92109397,
#        1.32609714, 0.60069815, 0.68126018, 0.5812236 , 0.45779257,
#        1.32307873, 1.07215821, 1.03447888, 0.4777055 , 0.85699819,
#        0.97581956, 1.31794882, 0.78259009, 0.35531549, 0.64938267,
#        0.85471191, 0.71992136, 0.67748182, 0.84652377, 0.81536883,
#        1.15839826, 1.14803217, 0.81255634, 0.93805571, 0.65536008,
#        0.94491915, 0.96326968, 0.65815734, 0.4525151 , 0.63443158,
#        1.07482198, 1.03757024, 0.52153453, 0.8055148 , 0.99426837,
#        0.8519003 , 0.63699346, 1.1068101 , 0.86274448, 0.41865969,
#        0.75369071, 1.09507956, 0.80478815, 0.53704041, 0.80338068,
#        0.68004377, 0.98789806, 0.77077506, 0.47670254, 0.75596257,
#        1.12512493, 0.77775644, 0.8342722 , 0.62551027, 1.12041812])

# %%
y_pred = ada_reg.predict(x_test)

r2_score(y_test, y_pred)
# Out:
# 0.8263992998594876

# %%
ada_reg = AdaBoostRegressor(DecisionTreeRegressor(max_depth=2), 
                           n_estimators=200, 
                           learning_rate=0.5) #usually set at 0.01 or 0.001 to prevent overfitting

ada_reg.fit(x_train, y_train)
# Out:
# AdaBoostRegressor(base_estimator=DecisionTreeRegressor(criterion='mse',
#                                                        max_depth=2,
#                                                        max_features=None,
#                                                        max_leaf_nodes=None,
#                                                        min_impurity_decrease=0.0,
#                                                        min_impurity_split=None,
#                                                        min_samples_leaf=1,
#                                                        min_samples_split=2,
#                                                        min_weight_fraction_leaf=0.0,
#                                                        presort=False,
#                                                        random_state=None,
#                                                        splitter='best'),
#                   learning_rate=0.5, loss='linear', n_estimators=200,
#                   random_state=None)

# %%
ada_reg.estimator_weights_
# Out:
# array([0.64878187, 0.57709925, 0.69374779, 0.42889581, 0.53548137,
#        0.35437436, 0.50646875, 0.41864503, 0.45502503, 0.41715165,
#        0.43190165, 0.49922636, 0.30560577, 0.25704685, 0.31398949,
#        0.46462399, 0.31317408, 0.56139081, 0.37064983, 0.21320009,
#        0.29440961, 0.3590134 , 0.35806752, 0.45168917, 0.17345379,
#        0.3810493 , 0.35326684, 0.48748187, 0.35013357, 0.24628105,
#        0.18417025, 0.50007814, 0.15748358, 0.46014733, 0.36041138,
#        0.28787901, 0.56996214, 0.30062073, 0.29009669, 0.38278062,
#        0.30001574, 0.46209871, 0.39874138, 0.47596928, 0.33405925,
#        0.27117352, 0.23500152, 0.42470806, 0.36313898, 0.17495144,
#        0.41770502, 0.5477699 , 0.40939985, 0.28673516, 0.18668511,
#        0.3444175 , 0.23415821, 0.45228335, 0.29500306, 0.30468814,
#        0.36698985, 0.46551182, 0.2882642 , 0.41578311, 0.28891542,
#        0.51266078, 0.36798033, 0.30323682, 0.24251906, 0.27722982,
#        0.23562604, 0.04515496, 0.2965756 , 0.15199597, 0.31283971,
#        0.44326997, 0.19561065, 0.2430199 , 0.39593902, 0.4857192 ,
#        0.35162899, 0.10836232, 0.2727526 , 0.24035673, 0.28626988,
#        0.45857715, 0.36954661, 0.32551814, 0.42458892, 0.21394677,
#        0.22462389, 0.14061612, 0.35464952, 0.25623857, 0.10867753,
#        0.32131554, 0.31510347, 0.0971027 , 0.41768919, 0.45338217,
#        0.53922784, 0.33557664, 0.33799727, 0.33413273, 0.26935552,
#        0.29343789, 0.39676974, 0.34082993, 0.39122366, 0.33578848,
#        0.18222043, 0.28632082, 0.20923388, 0.22387443, 0.51158694,
#        0.36955499, 0.15577599, 0.18788364, 0.33115515, 0.26023721,
#        0.2417723 , 0.39847808, 0.36567739, 0.32789089, 0.32881365,
#        0.44659766, 0.30303839, 0.36233507, 0.30294646, 0.18592484,
#        0.29791658, 0.44814005, 0.19486168, 0.13541119, 0.34877958,
#        0.52779178, 0.31586757, 0.14529523, 0.15950677, 0.51701391,
#        0.20971176, 0.29811645, 0.28055442, 0.0605843 , 0.21091213,
#        0.41298837, 0.09845813, 0.33207178, 0.20933265, 0.16571839,
#        0.16449488, 0.27597038, 0.27471229, 0.56720625, 0.47648795,
#        0.44354726, 0.17074577, 0.16099208, 0.10982825, 0.39294922,
#        0.24895231, 0.29392715, 0.17341659, 0.33797222, 0.41977312,
#        0.54643418, 0.41448395, 0.35677089, 0.1914703 , 0.43397242,
#        0.29037244, 0.41015916, 0.40741518, 0.20681528, 0.32229249,
#        0.16309565, 0.52792343, 0.30136386, 0.14181784, 0.22211641,
#        0.48701675, 0.1827792 , 0.29969216, 0.23513457, 0.11904152,
#        0.08790976, 0.29194231, 0.33989939, 0.07958396, 0.12618852,
#        0.7174214 , 0.21831652, 0.07716246, 0.32345057, 0.20598383,
#        0.28663522, 0.33996877, 0.32019552, 0.23907079, 0.32788278])

# %%
y_pred = ada_reg.predict(x_test)

r2_score(y_test, y_pred)
# Out:
# 0.6752949868638068

# %% [markdown]
# ### Gradient Boosting
#
# Gradient boosting sequentially adds predictors to an ensemble where each weak learner learns from the residuals of previous weak learners
#
# model1: y=A1+B1x+e1
# model2: e1=A2+B2x+e2
# model3: e2=A3+B3x+e3
# CombinedModel: y=A1+A2+A3+(B1+B2+B3)x+e4

# %%
tree_reg1 = DecisionTreeRegressor(max_depth=3)
tree_reg1.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=3, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
y2 = y_train - tree_reg1.predict(x_train)

tree_reg2 = DecisionTreeRegressor(max_depth=3)
tree_reg2.fit(x_train, y2)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=3, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
y3 = y2 - tree_reg2.predict(x_train)

tree_reg3 = DecisionTreeRegressor(max_depth=3)
tree_reg3.fit(x_train, y3)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=3, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
y_pred = sum(tree.predict(x_test) for tree in (tree_reg1, tree_reg2, tree_reg3))

# %%
r2_score(y_test, y_pred)
# Out:
# 0.7474566980305538

# %%
y4 = y3 - tree_reg3.predict(x_train)

tree_reg4 = DecisionTreeRegressor(max_depth=3)
tree_reg4.fit(x_train, y4)

y_pred = sum(tree.predict(x_test) for tree in (tree_reg1, tree_reg2, tree_reg3, tree_reg4))

r2_score(y_test, y_pred)
# Out:
# 0.7958107727816512

# %%
gbr = GradientBoostingRegressor(max_depth=3, n_estimators=3, learning_rate=1.0)

gbr.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#                           learning_rate=1.0, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=3,
#                           n_iter_no_change=None, presort='auto',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
y_pred = gbr.predict(x_test)

r2_score(y_test, y_pred)
# Out:
# 0.7474566980305538

# %%
gbr = GradientBoostingRegressor(max_depth=3, n_estimators=3, learning_rate=0.1)

gbr.fit(x_train, y_train)

y_pred = gbr.predict(x_test)

r2_score(y_test, y_pred)
# Out:
# 0.2999961312914349

# %%
gbr = GradientBoostingRegressor(max_depth=3, n_estimators=50, learning_rate=0.1)

gbr.fit(x_train, y_train)

y_pred = gbr.predict(x_test)

r2_score(y_test, y_pred)
# Out:
# 0.8927949990269481

# %% [markdown]
# ### hyperparameter tuning of gradient boosting trees
#
# 1) grid search
# 2) warm start and early stopping

# %% [markdown]
# #### using grid search

# %%
X = X.drop(['flyash', 'coarseaggregate', 'fineaggregate'], axis=1)

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
baseline = GradientBoostingRegressor(max_depth=3, n_estimators=50)
baseline.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#                           learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=50,
#                           n_iter_no_change=None, presort='auto',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
y_pred = baseline.predict(x_test)

r2_score(y_test, y_pred)
# Out:
# 0.9072646307921569

# %%
importance_features = pd.Series(baseline.feature_importances_, index=X.columns).sort_values(ascending=False)

importance_features
# Out:
# age                 0.366452
# cement              0.337295
# water               0.100123
# slag                0.099232
# superplasticizer    0.096898
# dtype: float64

# %%
gbr = GradientBoostingRegressor(max_depth=3)

parameters = {'n_estimators': [1, 5, 10, 50, 100, 200, 300, 400, 500] }

gridSearch_reg = GridSearchCV(estimator=gbr, param_grid=parameters, cv=3) #3fold cross-validation

# %%
gridSearch_reg.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=3, error_score='raise-deprecating',
#              estimator=GradientBoostingRegressor(alpha=0.9,
#                                                  criterion='friedman_mse',
#                                                  init=None, learning_rate=0.1,
#                                                  loss='ls', max_depth=3,
#                                                  max_features=None,
#                                                  max_leaf_nodes=None,
#                                                  min_impurity_decrease=0.0,
#                                                  min_impurity_split=None,
#                                                  min_samples_leaf=1,
#                                                  min_samples_split=2,
#                                                  min_weight_fraction_leaf=0.0,
#                                                  n_estimators=100,
#                                                  n_iter_no_change=None,
#                                                  presort='auto',
#                                                  random_state=None,
#                                                  subsample=1.0, tol=0.0001,
#                                                  validation_fraction=0.1,
#                                                  verbose=0, warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid={'n_estimators': [1, 5, 10, 50, 100, 200, 300, 400,
#                                           500]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
gridSearch_reg.best_params_
# Out:
# {'n_estimators': 500}

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2) #shuffle data again

gbr_best = GradientBoostingRegressor(max_depth=3,
                                     n_estimators=gridSearch_reg.best_params_['n_estimators'])

gbr_best.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#                           learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=500,
#                           n_iter_no_change=None, presort='auto',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
y_pred = gbr_best.predict(x_test)

r2_score(y_test, y_pred)
# Out:
# 0.9266305949351323

# %% [markdown]
# #### using warm start and early stopping

# %%
gbr = GradientBoostingRegressor(max_depth=3, warm_start=True)

# %%
min_val_error = float('inf')
error_increasing = 0

for n_estimators in range(1, 1000):
    gbr.n_estimators = n_estimators
    gbr.fit(x_train, y_train)
    
    y_pred = gbr.predict(x_test)
    val_error = mean_squared_error(y_test, y_pred)
    
    print('No. of estimators: ', gbr.n_estimators_)
    print('Validation error: ', val_error)
    
    if val_error < min_val_error:
        min_val_error = val_error
        error_increasing = 0
    else:
        error_increasing += 1
        if error_increasing == 10:
            break
# Out:
# No. of estimators:  1
# Validation error:  247.09671411536897
# No. of estimators:  2
# Validation error:  217.85131825208632
# No. of estimators:  3
# Validation error:  195.05598925393718
# No. of estimators:  4
# Validation error:  177.25936988023236
# No. of estimators:  5
# Validation error:  159.25391003470958
# No. of estimators:  6
# Validation error:  146.66132620161983
# No. of estimators:  7
# Validation error:  133.0130213725849
# No. of estimators:  8
# Validation error:  123.2145332667508
# No. of estimators:  9
# Validation error:  115.0040553143462
# No. of estimators:  10
# Validation error:  107.2372076475894
# No. of estimators:  11
# Validation error:  98.6093070101871
# No. of estimators:  12
# Validation error:  92.99796956110289
# No. of estimators:  13
# Validation error:  87.99477434001977
# No. of estimators:  14
# Validation error:  82.68805620695122
# No. of estimators:  15
# Validation error:  78.29380826946138
# No. of estimators:  16
# Validation error:  73.94983643062263
# No. of estimators:  17
# Validation error:  70.63940699305049
# No. of estimators:  18
# Validation error:  67.55102790465784
# No. of estimators:  19
# Validation error:  64.58987909077031
# No. of estimators:  20
# Validation error:  61.580924040040806
# No. of estimators:  21
# Validation error:  59.31694828149083
# No. of estimators:  22
# Validation error:  57.658265348078814
# No. of estimators:  23
# Validation error:  55.79746263557337
# No. of estimators:  24
# Validation error:  54.566340367627824
# No. of estimators:  25
# Validation error:  52.59267082394523
# No. of estimators:  26
# Validation error:  51.049931440222686
# No. of estimators:  27
# Validation error:  49.93648246405067
# No. of estimators:  28
# Validation error:  48.69171738170392
# No. of estimators:  29
# Validation error:  47.7582484808344
# No. of estimators:  30
# Validation error:  46.34302562004185
# No. of estimators:  31
# Validation error:  45.44322947169517
# No. of estimators:  32
# Validation error:  45.022015424139454
# No. of estimators:  33
# Validation error:  44.04617187623143
# No. of estimators:  34
# Validation error:  43.33289207182451
# No. of estimators:  35
# Validation error:  42.749420495775475
# No. of estimators:  36
# Validation error:  42.078338331644474
# No. of estimators:  37
# Validation error:  41.38403944275493
# No. of estimators:  38
# Validation error:  40.85195660986951
# No. of estimators:  39
# Validation error:  40.33547302418327
# No. of estimators:  40
# Validation error:  39.962426509237275
# No. of estimators:  41
# Validation error:  39.38286551077319
# No. of estimators:  42
# Validation error:  39.04102969706669
# No. of estimators:  43
# Validation error:  38.81827948524806
# No. of estimators:  44
# Validation error:  38.288004092639646
# No. of estimators:  45
# Validation error:  37.94617316290606
# No. of estimators:  46
# Validation error:  37.583843974635904
# No. of estimators:  47
# Validation error:  37.14746274202812
# No. of estimators:  48
# Validation error:  36.757169795113995
# No. of estimators:  49
# Validation error:  36.64024366124359
# No. of estimators:  50
# Validation error:  36.33549397371371
# No. of estimators:  51
# Validation error:  36.11229057402758
# No. of estimators:  52
# Validation error:  35.889153507054104
# No. of estimators:  53
# Validation error:  35.58206812025933
# No. of estimators:  54
# Validation error:  35.29962204869406
# No. of estimators:  55
# Validation error:  34.86984703593223
# No. of estimators:  56
# Validation error:  34.49932289122379
# No. of estimators:  57
# Validation error:  34.39617678497667
# No. of estimators:  58
# Validation error:  34.144385959533274
# No. of estimators:  59
# Validation error:  33.9895952853243
# No. of estimators:  60
# Validation error:  33.78743184676394
# No. of estimators:  61
# Validation error:  33.71348914458338
# No. of estimators:  62
# Validation error:  33.62845184433339
# No. of estimators:  63
# Validation error:  33.49782870131832
# No. of estimators:  64
# Validation error:  33.278360806109696
# No. of estimators:  65
# Validation error:  33.13159998672374
# No. of estimators:  66
# Validation error:  33.08855251677732
# No. of estimators:  67
# Validation error:  32.92735356201979
# No. of estimators:  68
# Validation error:  32.81244334502939
# No. of estimators:  69
# Validation error:  32.7711572698514
# No. of estimators:  70
# Validation error:  32.67015459911814
# No. of estimators:  71
# Validation error:  32.40351834336092
# No. of estimators:  72
# Validation error:  32.26067924073469
# No. of estimators:  73
# Validation error:  32.28394976787174
# No. of estimators:  74
# Validation error:  32.17201150937069
# No. of estimators:  75
# Validation error:  32.05676008284793
# No. of estimators:  76
# Validation error:  32.0273359995078
# No. of estimators:  77
# Validation error:  31.9055676887044
# No. of estimators:  78
# Validation error:  31.809926234587312
# No. of estimators:  79
# Validation error:  31.667201553586416
# No. of estimators:  80
# Validation error:  31.598242675397202
# No. of estimators:  81
# Validation error:  31.494499836907963
# No. of estimators:  82
# Validation error:  31.481870232122546
# No. of estimators:  83
# Validation error:  31.328904025590656
# No. of estimators:  84
# Validation error:  31.19236193725282
# No. of estimators:  85
# Validation error:  31.100334967462146
# No. of estimators:  86
# Validation error:  31.005886133148408
# No. of estimators:  87
# Validation error:  30.993726226174605
# No. of estimators:  88
# Validation error:  30.95320421627866
# No. of estimators:  89
# Validation error:  30.849684458339922
# No. of estimators:  90
# Validation error:  30.75323028985986
# No. of estimators:  91
# Validation error:  30.551684713988276
# No. of estimators:  92
# Validation error:  30.3777501047787
# No. of estimators:  93
# Validation error:  30.315760403891623
# No. of estimators:  94
# Validation error:  30.268854388508284
# No. of estimators:  95
# Validation error:  30.27546280842023
# No. of estimators:  96
# Validation error:  30.14688751391021
# No. of estimators:  97
# Validation error:  30.05104165226428
# No. of estimators:  98
# Validation error:  29.859932478085867
# No. of estimators:  99
# Validation error:  29.719524427722185
# No. of estimators:  100
# Validation error:  29.621827359736326
# No. of estimators:  101
# Validation error:  29.560633498976422
# No. of estimators:  102
# Validation error:  29.519076063582155
# No. of estimators:  103
# Validation error:  29.40494807288524
# No. of estimators:  104
# Validation error:  29.32126098692763
# No. of estimators:  105
# Validation error:  29.303435840063162
# No. of estimators:  106
# Validation error:  29.27643052407678
# No. of estimators:  107
# Validation error:  29.278423050296755
# No. of estimators:  108
# Validation error:  29.26527735990577
# No. of estimators:  109
# Validation error:  29.2011642447421
# No. of estimators:  110
# Validation error:  29.153255261596616
# No. of estimators:  111
# Validation error:  29.06297805208406
# No. of estimators:  112
# Validation error:  28.92685350961259
# No. of estimators:  113
# Validation error:  28.816699985665508
# No. of estimators:  114
# Validation error:  28.72319707584357
# No. of estimators:  115
# Validation error:  28.684658734466847
# No. of estimators:  116
# Validation error:  28.652870300021817
# No. of estimators:  117
# Validation error:  28.53794012987033
# No. of estimators:  118
# Validation error:  28.537728667193072
# No. of estimators:  119
# Validation error:  28.31228641351981
# No. of estimators:  120
# Validation error:  28.290577364950437
# No. of estimators:  121
# Validation error:  28.24101456433036
# No. of estimators:  122
# Validation error:  28.153430231048617
# No. of estimators:  123
# Validation error:  28.04464909322991
# No. of estimators:  124
# Validation error:  28.12063901519175
# No. of estimators:  125
# Validation error:  28.040465318008227
# No. of estimators:  126
# Validation error:  27.989229881906653
# No. of estimators:  127
# Validation error:  27.9416769339709
# No. of estimators:  128
# Validation error:  27.856380052452117
# No. of estimators:  129
# Validation error:  27.732884131022526
# No. of estimators:  130
# Validation error:  27.675433580678597
# No. of estimators:  131
# Validation error:  27.651555250221833
# No. of estimators:  132
# Validation error:  27.59558387676078
# No. of estimators:  133
# Validation error:  27.560789654622116
# No. of estimators:  134
# Validation error:  27.49214019500808
# No. of estimators:  135
# Validation error:  27.43337889130665
# No. of estimators:  136
# Validation error:  27.377813480913844
# No. of estimators:  137
# Validation error:  27.32775100477011
# No. of estimators:  138
# Validation error:  27.286709969448946
# No. of estimators:  139
# Validation error:  27.210570114415592
# No. of estimators:  140
# Validation error:  27.21390281136286
# No. of estimators:  141
# Validation error:  27.146609988557234
# No. of estimators:  142
# Validation error:  27.0695096905875
# No. of estimators:  143
# Validation error:  27.068607734625058
# No. of estimators:  144
# Validation error:  27.04315693830327
# No. of estimators:  145
# Validation error:  26.985974423063524
# No. of estimators:  146
# Validation error:  26.921249584027667
# No. of estimators:  147
# Validation error:  26.842442564180462
# No. of estimators:  148
# Validation error:  26.773209701620182
# No. of estimators:  149
# Validation error:  26.738439849127662
# No. of estimators:  150
# Validation error:  26.559537933764492
# No. of estimators:  151
# Validation error:  26.52971320206264
# No. of estimators:  152
# Validation error:  26.45834851871155
# No. of estimators:  153
# Validation error:  26.456510048725807
# No. of estimators:  154
# Validation error:  26.411304563287125
# No. of estimators:  155
# Validation error:  26.38895063600104
# No. of estimators:  156
# Validation error:  26.36842628480943
# No. of estimators:  157
# Validation error:  26.360027876734026
# No. of estimators:  158
# Validation error:  26.330698564345106
# No. of estimators:  159
# Validation error:  26.280812878951924
# No. of estimators:  160
# Validation error:  26.316954219408657
# No. of estimators:  161
# Validation error:  26.26242394911281
# No. of estimators:  162
# Validation error:  26.200579696928585
# No. of estimators:  163
# Validation error:  26.167266089735296
# No. of estimators:  164
# Validation error:  26.10075449615608
# No. of estimators:  165
# Validation error:  26.07290407638351
# No. of estimators:  166
# Validation error:  26.02252130341703
# No. of estimators:  167
# Validation error:  25.998899673786564
# No. of estimators:  168
# Validation error:  25.986731965788646
# No. of estimators:  169
# Validation error:  25.930021185657168
# No. of estimators:  170
# Validation error:  25.91474763327355
# No. of estimators:  171
# Validation error:  25.808337198890715
# No. of estimators:  172
# Validation error:  25.801140664882325
# No. of estimators:  173
# Validation error:  25.78523509244788
# No. of estimators:  174
# Validation error:  25.723955431441652
# No. of estimators:  175
# Validation error:  25.735223947689615
# No. of estimators:  176
# Validation error:  25.6985970336936
# No. of estimators:  177
# Validation error:  25.6547050997443
# No. of estimators:  178
# Validation error:  25.58408250539642
# No. of estimators:  179
# Validation error:  25.638001836743783
# No. of estimators:  180
# Validation error:  25.544857957422188
# No. of estimators:  181
# Validation error:  25.510826574312432
# No. of estimators:  182
# Validation error:  25.498725264523
# No. of estimators:  183
# Validation error:  25.488597341011786
# No. of estimators:  184
# Validation error:  25.460832419672677
# No. of estimators:  185
# Validation error:  25.45627123939519
# No. of estimators:  186
# Validation error:  25.450267709012692
# No. of estimators:  187
# Validation error:  25.44501463669971
# No. of estimators:  188
# Validation error:  25.393781624164774
# No. of estimators:  189
# Validation error:  25.436743348823114
# No. of estimators:  190
# Validation error:  25.393096748076093
# No. of estimators:  191
# Validation error:  25.292110177130162
# No. of estimators:  192
# Validation error:  25.262734463059054
# No. of estimators:  193
# Validation error:  25.25752744152696
# No. of estimators:  194
# Validation error:  25.235422080599104
# No. of estimators:  195
# Validation error:  25.18748817599416
# No. of estimators:  196
# Validation error:  25.214502714548146
# No. of estimators:  197
# Validation error:  25.18902214988965
# No. of estimators:  198
# Validation error:  25.200072536592494
# No. of estimators:  199
# Validation error:  25.169333866017475
# No. of estimators:  200
# Validation error:  25.15958793505993
# No. of estimators:  201
# Validation error:  25.156481305333706
# No. of estimators:  202
# Validation error:  25.152393152545194
# No. of estimators:  203
# Validation error:  25.20863312191457
# No. of estimators:  204
# Validation error:  25.182078495087314
# No. of estimators:  205
# Validation error:  25.151225164733134
# No. of estimators:  206
# Validation error:  25.119301849557353
# No. of estimators:  207
# Validation error:  25.0467593488185
# No. of estimators:  208
# Validation error:  25.06057065272391
# No. of estimators:  209
# Validation error:  25.06482596882647
# No. of estimators:  210
# Validation error:  25.000475496490175
# No. of estimators:  211
# Validation error:  25.006543292090956
# No. of estimators:  212
# Validation error:  24.974977793628664
# No. of estimators:  213
# Validation error:  24.95768664793421
# No. of estimators:  214
# Validation error:  24.935828705743873
# No. of estimators:  215
# Validation error:  24.93168717644244
# No. of estimators:  216
# Validation error:  24.87305823421029
# No. of estimators:  217
# Validation error:  24.85090118613913
# No. of estimators:  218
# Validation error:  24.839692288095005
# No. of estimators:  219
# Validation error:  24.8204960188877
# No. of estimators:  220
# Validation error:  24.800241564744397
# No. of estimators:  221
# Validation error:  24.774029262601204
# No. of estimators:  222
# Validation error:  24.699771847406115
# No. of estimators:  223
# Validation error:  24.761264900734645
# No. of estimators:  224
# Validation error:  24.694117417710956
# No. of estimators:  225
# Validation error:  24.618629945544836
# No. of estimators:  226
# Validation error:  24.60916016276042
# No. of estimators:  227
# Validation error:  24.579174449163776
# No. of estimators:  228
# Validation error:  24.549227760548582
# No. of estimators:  229
# Validation error:  24.54801628795201
# No. of estimators:  230
# Validation error:  24.54895209072344
# No. of estimators:  231
# Validation error:  24.543241786266883
# No. of estimators:  232
# Validation error:  24.53691818605607
# No. of estimators:  233
# Validation error:  24.602243818766418
# No. of estimators:  234
# Validation error:  24.581748201436383
# No. of estimators:  235
# Validation error:  24.546774847528468
# No. of estimators:  236
# Validation error:  24.493175600490307
# No. of estimators:  237
# Validation error:  24.42820914425572
# No. of estimators:  238
# Validation error:  24.349653021086983
# No. of estimators:  239
# Validation error:  24.315944905564198
# No. of estimators:  240
# Validation error:  24.297358373885633
# No. of estimators:  241
# Validation error:  24.264326651846247
# No. of estimators:  242
# Validation error:  24.242684205615628
# No. of estimators:  243
# Validation error:  24.24598220138469
# No. of estimators:  244
# Validation error:  24.235911461770936
# No. of estimators:  245
# Validation error:  24.232428079808074
# No. of estimators:  246
# Validation error:  24.171518084605857
# No. of estimators:  247
# Validation error:  24.167972167041103
# No. of estimators:  248
# Validation error:  24.19951524556302
# No. of estimators:  249
# Validation error:  24.198597791307918
# No. of estimators:  250
# Validation error:  24.194821759719197
# No. of estimators:  251
# Validation error:  24.18869013967324
# No. of estimators:  252
# Validation error:  24.14307509660807
# No. of estimators:  253
# Validation error:  24.141973199002482
# No. of estimators:  254
# Validation error:  24.208078477278036
# No. of estimators:  255
# Validation error:  24.221147152577483
# No. of estimators:  256
# Validation error:  24.18038909482819
# No. of estimators:  257
# Validation error:  24.141248348476058
# No. of estimators:  258
# Validation error:  24.138285435210303
# No. of estimators:  259
# Validation error:  24.023704710096087
# No. of estimators:  260
# Validation error:  23.998132033021545
# No. of estimators:  261
# Validation error:  23.91713299017216
# No. of estimators:  262
# Validation error:  23.919000771906628
# No. of estimators:  263
# Validation error:  23.888808517923405
# No. of estimators:  264
# Validation error:  23.8247236464803
# No. of estimators:  265
# Validation error:  23.786477154584283
# No. of estimators:  266
# Validation error:  23.781408204159103
# No. of estimators:  267
# Validation error:  23.778546361793655
# No. of estimators:  268
# Validation error:  23.75634251922455
# No. of estimators:  269
# Validation error:  23.748868184201818
# No. of estimators:  270
# Validation error:  23.758993076745853
# No. of estimators:  271
# Validation error:  23.736194517258916
# No. of estimators:  272
# Validation error:  23.738332001682316
# No. of estimators:  273
# Validation error:  23.759566505682535
# No. of estimators:  274
# Validation error:  23.7480109859524
# No. of estimators:  275
# Validation error:  23.722284342642833
# No. of estimators:  276
# Validation error:  23.703067014378302
# No. of estimators:  277
# Validation error:  23.71267198655452
# No. of estimators:  278
# Validation error:  23.666718415180018
# No. of estimators:  279
# Validation error:  23.55733404804619
# No. of estimators:  280
# Validation error:  23.554727769584698
# No. of estimators:  281
# Validation error:  23.502366154934517
# No. of estimators:  282
# Validation error:  23.47007286266979
# No. of estimators:  283
# Validation error:  23.39181376990298
# No. of estimators:  284
# Validation error:  23.427292724150426
# No. of estimators:  285
# Validation error:  23.40828866017189
# No. of estimators:  286
# Validation error:  23.328692971801306
# No. of estimators:  287
# Validation error:  23.30833173828902
# No. of estimators:  288
# Validation error:  23.27293130453999
# No. of estimators:  289
# Validation error:  23.250324010652896
# No. of estimators:  290
# Validation error:  23.238561277379684
# No. of estimators:  291
# Validation error:  23.20957362804191
# No. of estimators:  292
# Validation error:  23.16467800029386
# No. of estimators:  293
# Validation error:  23.141705446290555
# No. of estimators:  294
# Validation error:  23.157763915545637
# No. of estimators:  295
# Validation error:  23.132795675781747
# No. of estimators:  296
# Validation error:  23.12356772727035
# No. of estimators:  297
# Validation error:  23.083925048840793
# No. of estimators:  298
# Validation error:  23.065526463731974
# No. of estimators:  299
# Validation error:  23.054567839041777
# No. of estimators:  300
# Validation error:  23.017684767297087
# No. of estimators:  301
# Validation error:  23.016249354145092
# No. of estimators:  302
# Validation error:  22.994517288631837
# No. of estimators:  303
# Validation error:  22.987374938549745
# No. of estimators:  304
# Validation error:  22.959609774539427
# No. of estimators:  305
# Validation error:  22.942807383657268
# No. of estimators:  306
# Validation error:  22.933229228984036
# No. of estimators:  307
# Validation error:  22.940333943872115
# No. of estimators:  308
# Validation error:  22.93526309112921
# No. of estimators:  309
# Validation error:  22.901296702184222
# No. of estimators:  310
# Validation error:  22.906054108734555
# No. of estimators:  311
# Validation error:  22.89889446649197
# No. of estimators:  312
# Validation error:  22.897058062400735
# No. of estimators:  313
# Validation error:  22.886637825190196
# No. of estimators:  314
# Validation error:  22.807048656281292
# No. of estimators:  315
# Validation error:  22.785733786828494
# No. of estimators:  316
# Validation error:  22.785091529295066
# No. of estimators:  317
# Validation error:  22.775896455259637
# No. of estimators:  318
# Validation error:  22.76417617059338
# No. of estimators:  319
# Validation error:  22.776035665052273
# No. of estimators:  320
# Validation error:  22.784418099109978
# No. of estimators:  321
# Validation error:  22.742104592878693
# No. of estimators:  322
# Validation error:  22.706774042040724
# No. of estimators:  323
# Validation error:  22.672673842619485
# No. of estimators:  324
# Validation error:  22.644598646881647
# No. of estimators:  325
# Validation error:  22.632260379153465
# No. of estimators:  326
# Validation error:  22.634885914267667
# No. of estimators:  327
# Validation error:  22.629868521447605
# No. of estimators:  328
# Validation error:  22.58019312228444
# No. of estimators:  329
# Validation error:  22.57663824634196
# No. of estimators:  330
# Validation error:  22.54750182611346
# No. of estimators:  331
# Validation error:  22.557661296825792
# No. of estimators:  332
# Validation error:  22.5729742510179
# No. of estimators:  333
# Validation error:  22.55433292572869
# No. of estimators:  334
# Validation error:  22.54778789757609
# No. of estimators:  335
# Validation error:  22.53055605185302
# No. of estimators:  336
# Validation error:  22.516189787153383
# No. of estimators:  337
# Validation error:  22.506127428508968
# No. of estimators:  338
# Validation error:  22.501362458613542
# No. of estimators:  339
# Validation error:  22.498124554982667
# No. of estimators:  340
# Validation error:  22.516498244473663
# No. of estimators:  341
# Validation error:  22.515746364520613
# No. of estimators:  342
# Validation error:  22.506473199195735
# No. of estimators:  343
# Validation error:  22.52226663973522
# No. of estimators:  344
# Validation error:  22.51143758111148
# No. of estimators:  345
# Validation error:  22.482277776856233
# No. of estimators:  346
# Validation error:  22.473747450748657
# No. of estimators:  347
# Validation error:  22.418706356474626
# No. of estimators:  348
# Validation error:  22.43656318453827
# No. of estimators:  349
# Validation error:  22.35752852991946
# No. of estimators:  350
# Validation error:  22.347487356851847
# No. of estimators:  351
# Validation error:  22.3730865800044
# No. of estimators:  352
# Validation error:  22.358899585315715
# No. of estimators:  353
# Validation error:  22.349038642938062
# No. of estimators:  354
# Validation error:  22.337034561866076
# No. of estimators:  355
# Validation error:  22.296366591401508
# No. of estimators:  356
# Validation error:  22.291714429443093
# No. of estimators:  357
# Validation error:  22.277546199850587
# No. of estimators:  358
# Validation error:  22.27472265932343
# No. of estimators:  359
# Validation error:  22.280637477012004
# No. of estimators:  360
# Validation error:  22.281928179876463
# No. of estimators:  361
# Validation error:  22.25236384135582
# No. of estimators:  362
# Validation error:  22.193609227433104
# No. of estimators:  363
# Validation error:  22.162935783021148
# No. of estimators:  364
# Validation error:  22.13120404749163
# No. of estimators:  365
# Validation error:  22.12401067280096
# No. of estimators:  366
# Validation error:  22.116463546318997
# No. of estimators:  367
# Validation error:  22.11703847643437
# No. of estimators:  368
# Validation error:  22.10980283367638
# No. of estimators:  369
# Validation error:  22.10741644648775
# No. of estimators:  370
# Validation error:  22.10934876242261
# No. of estimators:  371
# Validation error:  22.097140985886142
# No. of estimators:  372
# Validation error:  22.088439909012298
# No. of estimators:  373
# Validation error:  22.08135181056261
# No. of estimators:  374
# Validation error:  22.045349573878763
# No. of estimators:  375
# Validation error:  22.028919425252365
# No. of estimators:  376
# Validation error:  22.00074686136563
# No. of estimators:  377
# Validation error:  21.967113527708428
# No. of estimators:  378
# Validation error:  21.931912854366406
# No. of estimators:  379
# Validation error:  21.910541553497318
# No. of estimators:  380
# Validation error:  21.893363662695823
# No. of estimators:  381
# Validation error:  21.890466713459734
# No. of estimators:  382
# Validation error:  21.880250233279437
# No. of estimators:  383
# Validation error:  21.866707099486444
# No. of estimators:  384
# Validation error:  21.841937348595877
# No. of estimators:  385
# Validation error:  21.82433923087658
# No. of estimators:  386
# Validation error:  21.810698568011524
# No. of estimators:  387
# Validation error:  21.82076386485315
# No. of estimators:  388
# Validation error:  21.81222689363119
# No. of estimators:  389
# Validation error:  21.79841893348905
# No. of estimators:  390
# Validation error:  21.797778757135237
# No. of estimators:  391
# Validation error:  21.797227974561114
# No. of estimators:  392
# Validation error:  21.778125446793222
# No. of estimators:  393
# Validation error:  21.74022396960698
# No. of estimators:  394
# Validation error:  21.740906448614766
# No. of estimators:  395
# Validation error:  21.69356597219505
# No. of estimators:  396
# Validation error:  21.68699002795021
# No. of estimators:  397
# Validation error:  21.655262604869222
# No. of estimators:  398
# Validation error:  21.663899999469596
# No. of estimators:  399
# Validation error:  21.641392180870895
# No. of estimators:  400
# Validation error:  21.606998647205916
# No. of estimators:  401
# Validation error:  21.606336398167297
# No. of estimators:  402
# Validation error:  21.58752080591409
# No. of estimators:  403
# Validation error:  21.578384054529874
# No. of estimators:  404
# Validation error:  21.572147405360845
# No. of estimators:  405
# Validation error:  21.539692320405557
# No. of estimators:  406
# Validation error:  21.535655061404814
# No. of estimators:  407
# Validation error:  21.527455610667964
# No. of estimators:  408
# Validation error:  21.53059036008943
# No. of estimators:  409
# Validation error:  21.502875341048053
# No. of estimators:  410
# Validation error:  21.48545347320583
# No. of estimators:  411
# Validation error:  21.48327476933062
# No. of estimators:  412
# Validation error:  21.46104725685048
# No. of estimators:  413
# Validation error:  21.441578630981482
# No. of estimators:  414
# Validation error:  21.42816533928073
# No. of estimators:  415
# Validation error:  21.422319694628435
# No. of estimators:  416
# Validation error:  21.401202560108988
# No. of estimators:  417
# Validation error:  21.38198022519884
# No. of estimators:  418
# Validation error:  21.375782142317238
# No. of estimators:  419
# Validation error:  21.382377853386846
# No. of estimators:  420
# Validation error:  21.36206179143756
# No. of estimators:  421
# Validation error:  21.333665604315986
# No. of estimators:  422
# Validation error:  21.324476512406093
# No. of estimators:  423
# Validation error:  21.312212596190275
# No. of estimators:  424
# Validation error:  21.299354510971913
# No. of estimators:  425
# Validation error:  21.288058068868782
# No. of estimators:  426
# Validation error:  21.288302089035806
# No. of estimators:  427
# Validation error:  21.265048790078765
# No. of estimators:  428
# Validation error:  21.26051420243857
# No. of estimators:  429
# Validation error:  21.242299380597917
# No. of estimators:  430
# Validation error:  21.24054729247757
# No. of estimators:  431
# Validation error:  21.23947303115706
# No. of estimators:  432
# Validation error:  21.243040306200214
# No. of estimators:  433
# Validation error:  21.241832639685548
# No. of estimators:  434
# Validation error:  21.214487381378095
# No. of estimators:  435
# Validation error:  21.197769704564358
# No. of estimators:  436
# Validation error:  21.179398065845668
# No. of estimators:  437
# Validation error:  21.1678734545952
# No. of estimators:  438
# Validation error:  21.167586548656598
# No. of estimators:  439
# Validation error:  21.166259547393395
# No. of estimators:  440
# Validation error:  21.168615195292535
# No. of estimators:  441
# Validation error:  21.15629719116248
# No. of estimators:  442
# Validation error:  21.132492720969953
# No. of estimators:  443
# Validation error:  21.138125720002428
# No. of estimators:  444
# Validation error:  21.162211252366564
# No. of estimators:  445
# Validation error:  21.16410284536728
# No. of estimators:  446
# Validation error:  21.149557847264223
# No. of estimators:  447
# Validation error:  21.160104643857917
# No. of estimators:  448
# Validation error:  21.15673071471004
# No. of estimators:  449
# Validation error:  21.149509150074124
# No. of estimators:  450
# Validation error:  21.065610122642212
# No. of estimators:  451
# Validation error:  21.00528744301114
# No. of estimators:  452
# Validation error:  20.998591659397665
# No. of estimators:  453
# Validation error:  20.99551537917689
# No. of estimators:  454
# Validation error:  20.97848337680359
# No. of estimators:  455
# Validation error:  20.99079894283213
# No. of estimators:  456
# Validation error:  20.95820902642173
# No. of estimators:  457
# Validation error:  20.95373734184128
# No. of estimators:  458
# Validation error:  20.943506442108628
# No. of estimators:  459
# Validation error:  20.934936562444452
# No. of estimators:  460
# Validation error:  20.942266275499712
# No. of estimators:  461
# Validation error:  20.931081743914323
# No. of estimators:  462
# Validation error:  20.924931836107092
# No. of estimators:  463
# Validation error:  20.923352931141018
# No. of estimators:  464
# Validation error:  20.926051781854046
# No. of estimators:  465
# Validation error:  20.915320947640016
# No. of estimators:  466
# Validation error:  20.87371535526567
# No. of estimators:  467
# Validation error:  20.878662955059262
# No. of estimators:  468
# Validation error:  20.898382763632785
# No. of estimators:  469
# Validation error:  20.88678752642147
# No. of estimators:  470
# Validation error:  20.842381565438178
# No. of estimators:  471
# Validation error:  20.855927672441236
# No. of estimators:  472
# Validation error:  20.821191877154437
# No. of estimators:  473
# Validation error:  20.83765153834711
# No. of estimators:  474
# Validation error:  20.842428285945704
# No. of estimators:  475
# Validation error:  20.842229486778848
# No. of estimators:  476
# Validation error:  20.85730415401776
# No. of estimators:  477
# Validation error:  20.842668311281937
# No. of estimators:  478
# Validation error:  20.82812634924588
# No. of estimators:  479
# Validation error:  20.779312390151894
# No. of estimators:  480
# Validation error:  20.795593321092554
# No. of estimators:  481
# Validation error:  20.804062670278647
# No. of estimators:  482
# Validation error:  20.785430517255076
# No. of estimators:  483
# Validation error:  20.74607699783742
# No. of estimators:  484
# Validation error:  20.74021118355926
# No. of estimators:  485
# Validation error:  20.705501973491135
# No. of estimators:  486
# Validation error:  20.694494633770113
# No. of estimators:  487
# Validation error:  20.67697292896943
# No. of estimators:  488
# Validation error:  20.67559775708778
# No. of estimators:  489
# Validation error:  20.674885357774816
# No. of estimators:  490
# Validation error:  20.672541032910782
# No. of estimators:  491
# Validation error:  20.669460846415355
# No. of estimators:  492
# Validation error:  20.653293627965976
# No. of estimators:  493
# Validation error:  20.6559829312773
# No. of estimators:  494
# Validation error:  20.662721975248
# No. of estimators:  495
# Validation error:  20.63848790400259
# No. of estimators:  496
# Validation error:  20.638231577202117
# No. of estimators:  497
# Validation error:  20.64027738485474
# No. of estimators:  498
# Validation error:  20.652583490805497
# No. of estimators:  499
# Validation error:  20.647613336518095
# No. of estimators:  500
# Validation error:  20.65470856752969
# No. of estimators:  501
# Validation error:  20.64243489563509
# No. of estimators:  502
# Validation error:  20.632211757457135
# No. of estimators:  503
# Validation error:  20.627786932923954
# No. of estimators:  504
# Validation error:  20.609310385342535
# No. of estimators:  505
# Validation error:  20.609055887839894
# No. of estimators:  506
# Validation error:  20.606094146013188
# No. of estimators:  507
# Validation error:  20.587085889540372
# No. of estimators:  508
# Validation error:  20.590239073281204
# No. of estimators:  509
# Validation error:  20.571080369500326
# No. of estimators:  510
# Validation error:  20.577883229299513
# No. of estimators:  511
# Validation error:  20.562262637876152
# No. of estimators:  512
# Validation error:  20.558392862649175
# No. of estimators:  513
# Validation error:  20.56467372175639
# No. of estimators:  514
# Validation error:  20.54261400548187
# No. of estimators:  515
# Validation error:  20.553135627117694
# No. of estimators:  516
# Validation error:  20.54565636299851
# No. of estimators:  517
# Validation error:  20.549574134642555
# No. of estimators:  518
# Validation error:  20.517578018774604
# No. of estimators:  519
# Validation error:  20.472734475451723
# No. of estimators:  520
# Validation error:  20.471505037374314
# No. of estimators:  521
# Validation error:  20.465023921668582
# No. of estimators:  522
# Validation error:  20.456710037639553
# No. of estimators:  523
# Validation error:  20.47337762117401
# No. of estimators:  524
# Validation error:  20.453610483686592
# No. of estimators:  525
# Validation error:  20.429188170083066
# No. of estimators:  526
# Validation error:  20.453800149806938
# No. of estimators:  527
# Validation error:  20.44824624902539
# No. of estimators:  528
# Validation error:  20.454895323826698
# No. of estimators:  529
# Validation error:  20.444466169757803
# No. of estimators:  530
# Validation error:  20.43232848064374
# No. of estimators:  531
# Validation error:  20.437441098604793
# No. of estimators:  532
# Validation error:  20.432972743001795
# No. of estimators:  533
# Validation error:  20.428670806110173
# No. of estimators:  534
# Validation error:  20.430959435874314
# No. of estimators:  535
# Validation error:  20.431015368327518
# No. of estimators:  536
# Validation error:  20.450997087257292
# No. of estimators:  537
# Validation error:  20.455189259430767
# No. of estimators:  538
# Validation error:  20.43725063363287
# No. of estimators:  539
# Validation error:  20.428223496518427
# No. of estimators:  540
# Validation error:  20.43270352852704
# No. of estimators:  541
# Validation error:  20.434202796338557
# No. of estimators:  542
# Validation error:  20.433003895800102
# No. of estimators:  543
# Validation error:  20.429647514758393
# No. of estimators:  544
# Validation error:  20.42850280223717
# No. of estimators:  545
# Validation error:  20.429246687981923
# No. of estimators:  546
# Validation error:  20.423932687770655
# No. of estimators:  547
# Validation error:  20.40280147042126
# No. of estimators:  548
# Validation error:  20.450325678220597
# No. of estimators:  549
# Validation error:  20.447358747303376
# No. of estimators:  550
# Validation error:  20.443203600596807
# No. of estimators:  551
# Validation error:  20.442248513803293
# No. of estimators:  552
# Validation error:  20.421970084855534
# No. of estimators:  553
# Validation error:  20.434536148096225
# No. of estimators:  554
# Validation error:  20.442309658994763
# No. of estimators:  555
# Validation error:  20.448635513967105
# No. of estimators:  556
# Validation error:  20.433682168177963
# No. of estimators:  557
# Validation error:  20.445746086540446

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2) #shuffle data again

gbr_best = GradientBoostingRegressor(max_depth=3,
                                     n_estimators=n_estimators)

gbr_best.fit(x_train, y_train)

y_pred = gbr_best.predict(x_test)

r2_score(y_test, y_pred)
# Out:
# 0.8985604135183776
